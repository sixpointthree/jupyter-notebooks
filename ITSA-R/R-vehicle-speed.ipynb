# %%
import pandas as pd

# %%
data = pd.read_csv("./vehicle_overland.csv")
data # print
# Out:
#      RPM;speed
# 0        955;0
# 1       1405;0
# 2       1929;0
# 3       1707;0
# 4       1762;7
# ...        ...
# 1843     725;4
# 1844     781;0
# 1845     758;0
# 1846     770;0
# 1847     788;0
#
# [1848 rows x 1 columns]

# %%
import numpy as np

rpm, speed = np.array(0), np.array(0)
for row in data["RPM;speed"]:
    rpm_temp, speed_temp = row.split(";")
    rpm = np.append(rpm, int(rpm_temp))
    speed = np.append(speed, int(speed_temp))
    
print(rpm)
print(speed)
# Out:
# [   0  955 1405 ...  758  770  788]
# [0 0 0 ... 0 0 0]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

plt.plot(speed)
plt.show()

# %%
# eliminate outlier
for i in range(speed.shape[0]):
    if speed[i] > 125:
        speed[i] = speed[i-1]

# %%
x = np.linspace(0, len(speed) - 1, len(speed))
print(x)

speed_mean = np.mean(speed)
speed_min = np.min(speed)
speed_max = np.max(speed)
speed_std = np.std(speed)
# Out:
# [0.000e+00 1.000e+00 2.000e+00 ... 1.846e+03 1.847e+03 1.848e+03]

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero') # Setzt Aches auf y = 0
ax.spines['right'].set_color('none') # Entfernt Achse rechts
ax.spines['top'].set_color('none') # Entfernt Achse oben

ax.set_title(f"Mean: {speed_mean:.2f}, Min: {speed_min}, Max: {speed_max}, std deviation: {speed_std:.2f}")

plt.axhline(y=speed_mean, color="black")
plt.axhline(y=speed_mean-speed_std, color="gray")
plt.axhline(y=speed_mean+speed_std, color="gray")
plt.plot(speed)

# %%
plt.hist(speed, density=1, bins=50)
plt.show()
